# %%
from PIL import Image
import PIL
import numpy as np

# %%
X = []
y = []

# %%
class_dict = {
    0 : "noise",
    1 : "one_finger",
    2 : "two_fingers",
    3 : "three_fingers",
    4 : "four_fingers",
    5 : "five_fingers",
    6 : "fist",
    7 : "thumbs_up",
    8 : "thumbs_down",
    9 : "okay",
    10: "c_hand"
}

# %%
for i in range(1000):
  for j in range(11):
    X.append(np.array(Image.open("data/images/" + str(j) + "/" + class_dict[j] + str(i) + ".png").resize((125,125), PIL.Image.ANTIALIAS)))
    y.append(j)

# %%
X = np.array(X)
y = np.array(y)

# %%
import matplotlib.pyplot as plt
plt.imshow(X[180])

# %%
import tensorflow.keras
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, Flatten
from tensorflow.keras.layers import Conv2D, MaxPooling2D
from tensorflow.keras import backend as K
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.losses import categorical_crossentropy

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)
X_train = X_train.astype('float32')
X_test = X_test.astype('float32')
X_train /= 255
X_test /= 255
print('x_train shape:', X_train.shape)
print(X_train.shape[0], 'train samples')
print(X_test.shape[0], 'test samples')
# Out:
# x_train shape: (8800, 125, 125)
# 8800 train samples
# 2200 test samples

# %%
num_classes = 11
y_train = tensorflow.keras.utils.to_categorical(y_train, num_classes)
y_test = tensorflow.keras.utils.to_categorical(y_test, num_classes)

# %%
X_test.shape[0]
# Out:
# 2200

# %%
img_rows, img_cols = 125, 125

X_train = X_train.reshape((X_train.shape[0], 125, 125, 1))
X_test = X_test.reshape((X_test.shape[0], 125, 125, 1))

# %%
model = Sequential()
model.add(Conv2D(32, kernel_size=(5, 5),
                 activation='relu',
                 input_shape=(125, 125, 1)))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Conv2D(64, (3, 3), activation='relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Conv2D(64, (3, 3), activation='relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.25))
model.add(Flatten())
model.add(Dense(128, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(num_classes, activation='softmax'))

model.compile(loss=categorical_crossentropy,
              optimizer=Adam(),
              metrics=['accuracy'])

history = model.fit(X_train, y_train,
          batch_size=32,
          epochs=20,
          verbose=1,
          validation_data=(X_test, y_test))
score = model.evaluate(X_test, y_test, verbose=1)
# Out:
# Train on 8800 samples, validate on 2200 samples
# Epoch 1/20
# WARNING:tensorflow:Entity <function Function._initialize_uninitialized_variables.<locals>.initialize_variables at 0x7fd521e97550> could not be transformed and will be executed as-is. Please report this to the AutoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: module 'gast' has no attribute 'Num'
# WARNING: Entity <function Function._initialize_uninitialized_variables.<locals>.initialize_variables at 0x7fd521e97550> could not be transformed and will be executed as-is. Please report this to the AutoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: module 'gast' has no attribute 'Num'
# 8800/8800 [==============================] - 7s 788us/sample - loss: 1.1411 - accuracy: 0.6227 - val_loss: 0.3975 - val_accuracy: 0.8845
# Epoch 2/20
# 8800/8800 [==============================] - 6s 723us/sample - loss: 0.4264 - accuracy: 0.8711 - val_loss: 0.2058 - val_accuracy: 0.9477
# Epoch 3/20
# 8800/8800 [==============================] - 7s 739us/sample - loss: 0.2719 - accuracy: 0.9181 - val_loss: 0.1748 - val_accuracy: 0.9550
# Epoch 4/20
# 8800/8800 [==============================] - 7s 743us/sample - loss: 0.2077 - accuracy: 0.9413 - val_loss: 0.1457 - val_accuracy: 0.9618
# Epoch 5/20
# 8800/8800 [==============================] - 7s 745us/sample - loss: 0.1702 - accuracy: 0.9503 - val_loss: 0.1463 - val_accuracy: 0.9609
# Epoch 6/20
# 8800/8800 [==============================] - 6s 722us/sample - loss: 0.1557 - accuracy: 0.9567 - val_loss: 0.1352 - val_accuracy: 0.9700
# Epoch 7/20
# 8800/8800 [==============================] - 6s 717us/sample - loss: 0.1292 - accuracy: 0.9617 - val_loss: 0.1245 - val_accuracy: 0.9741
# Epoch 8/20
# 8800/8800 [==============================] - 6s 717us/sample - loss: 0.1313 - accuracy: 0.9642 - val_loss: 0.1221 - val_accuracy: 0.9736
# Epoch 9/20
# 8800/8800 [==============================] - 6s 720us/sample - loss: 0.1212 - accuracy: 0.9678 - val_loss: 0.1311 - val_accuracy: 0.9705
# Epoch 10/20
# 8800/8800 [==============================] - 6s 717us/sample - loss: 0.1132 - accuracy: 0.9706 - val_loss: 0.1251 - val_accuracy: 0.9709
# Epoch 11/20
# 8800/8800 [==============================] - 6s 717us/sample - loss: 0.1183 - accuracy: 0.9678 - val_loss: 0.1317 - val_accuracy: 0.9732
# Epoch 12/20
# 8800/8800 [==============================] - 6s 716us/sample - loss: 0.1147 - accuracy: 0.9701 - val_loss: 0.1437 - val_accuracy: 0.9695
# Epoch 13/20
# 8800/8800 [==============================] - 6s 716us/sample - loss: 0.1079 - accuracy: 0.9711 - val_loss: 0.1232 - val_accuracy: 0.9777
# Epoch 14/20
# 8800/8800 [==============================] - 6s 716us/sample - loss: 0.0967 - accuracy: 0.9768 - val_loss: 0.1271 - val_accuracy: 0.9764
# Epoch 15/20
# 8800/8800 [==============================] - 6s 717us/sample - loss: 0.1027 - accuracy: 0.9727 - val_loss: 0.1360 - val_accuracy: 0.9768
# Epoch 16/20
# 8800/8800 [==============================] - 6s 739us/sample - loss: 0.0961 - accuracy: 0.9761 - val_loss: 0.1401 - val_accuracy: 0.9759
# Epoch 17/20
# 8800/8800 [==============================] - 7s 740us/sample - loss: 0.0968 - accuracy: 0.9755 - val_loss: 0.1299 - val_accuracy: 0.9750
# Epoch 18/20
# 8800/8800 [==============================] - 6s 736us/sample - loss: 0.0855 - accuracy: 0.9802 - val_loss: 0.1403 - val_accuracy: 0.9759
# Epoch 19/20
# 8800/8800 [==============================] - 6s 727us/sample - loss: 0.0934 - accuracy: 0.9768 - val_loss: 0.1315 - val_accuracy: 0.9755
# Epoch 20/20
# 8800/8800 [==============================] - 6s 715us/sample - loss: 0.0852 - accuracy: 0.9777 - val_loss: 0.1373 - val_accuracy: 0.9764
# 2200/1 [======================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================== ...

# %%
plt.plot(history.history['accuracy'], label='Train')
plt.plot(history.history['val_accuracy'], label='Test')
plt.legend()

# %%
model.save_weights('GestureModel.h5')
